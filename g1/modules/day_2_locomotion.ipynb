# %%
from sdk_client import Robot
rob = Robot("eth0")

# %%
import time
rob.walk(0.5,0.0,0.0)
time.sleep(5)
rob.stop()

# %%
rob.turn_for(-45)

# %%
rob.fsm_1_damp()

# %%
rob.fsm_0_zt()

# %%
rob.get_joint_position(1)
# Out:
# -0.020325245335698128

# %%
rob.get_imu()
# Out:
# ImuData(rpy=(0.005489351227879524, -0.0006343746790662408, -0.31744518876075745), gyro=(0.0, 0.0, 0.0), acc=(0.0, 0.0, 0.0), quat=(0.9874264001846313, 0.0026600384153425694, -0.0007470137788914144, -0.15805552899837494), temp=0.0)

# %%
rob.get_odom_pose()

# %%
rob.get_slam_info()

# %%
rob.get_slam_pose()
# Out:
# (0.0, 0.0, 0.0)

# %%
rob.hanged_boot()
# Out:
# damp         -> FSM 1   mode 0
# stand_up     -> FSM 4   mode 1
# height 0.02 m -> FSM 4   mode 1
# height 0.04 m -> FSM 4   mode 1
# height 0.06 m -> FSM 4   mode 1
# height 0.08 m -> FSM 4   mode 1
# height 0.10 m -> FSM 4   mode 1
# height 0.12 m -> FSM 4   mode 1
# height 0.14 m -> FSM 4   mode 1
# height 0.16 m -> FSM 4   mode 1
# height 0.18 m -> FSM 4   mode 0
# height 0.20 m -> FSM 4   mode 0
# height 0.22 m -> FSM 4   mode 0
# balance      -> FSM 4   mode 0
# height_ok    -> FSM 4   mode 0
# start        -> FSM 4   mode 0
# balanced     -> FSM 501   mode 0

# %%
rob.get_robot_state()
# Out:
# {'fsm': {'id': 501, 'mode': 0},
#  'mode': 0,
#  'gait': 0,
#  'body_height': 0.0,
#  'position': (0.08441182971000671, -0.2697998583316803, 0.7093150615692139),
#  'velocity': (1.4666599668089475e-07,
#   7.132555168709587e-08,
#   -1.9918541482866203e-08),
#  'yaw': -0.3029848635196686,
#  'is_moving': False,
#  'imu': ImuData(rpy=(0.003081446047872305, 0.0442102812230587, -0.3029848635196686), gyro=(0.0, 0.0, 0.0), acc=(0.0, 0.0, 0.0), quat=(0.9882990717887878, 0.004858396016061306, 0.0216177050024271, -0.15091024339199066), temp=0.0),
#  'odom_pose': None,
#  'slam_pose': (0.0, 0.0, 0.0),
#  'joint_count': 35,
#  'sensor_timestamps': {'sport': 1777195404.6827507,
#   'lidar_map': 0.0,
#   'lidar_cloud': 0.0,
#   'lowstate': 1777195404.682486,
#   'odom': 0.0},
#  'sensor_stale': {'sport': False,
#   'lidar_map': True,
#   'lidar_cloud': True,
#   'lowstate': False,
#   'odom': True},
#  'slam_is_running': False,
#  'queued_path_points': 0}

# %%
rob.hand_close("right")

# %%
rob.hand_open("right")

# %%
rob.set_gait_type(0)
# Out:
# 0
