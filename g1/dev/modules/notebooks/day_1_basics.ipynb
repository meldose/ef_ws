# %%
from sdk_client import Robot
rob = Robot("eth0")

# %%
rob.say("Hi")
# Out:
# 3104

# %%
for _ in range(60):
    rob.headlight("red",100,1)
# Out:
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error
# [Future] future wait error

# %%
from rich import inspect
inspect(rob,all=True)
