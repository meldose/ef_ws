# %%
from sdk_client import Robot
import time
import math
rob = Robot("eth0")

# %%
rob.damp()
rob.hanged_boot()
# Out:
# stand_up command -> SetFsmId(4)
# stand_up     -> FSM 4   mode 1
# height 0.02 m command -> SetStandHeight
# height 0.02 m -> FSM None   mode 0
# height 0.04 m command -> SetStandHeight
# height 0.04 m -> FSM 4   mode 0
# height 0.06 m command -> SetStandHeight
# height 0.06 m -> FSM 4   mode 0
# height 0.08 m command -> SetStandHeight
# height 0.08 m -> FSM None   mode 0
# height 0.10 m command -> SetStandHeight
# height 0.10 m -> FSM 4   mode 0
# height 0.12 m command -> SetStandHeight
# height 0.12 m -> FSM 4   mode 0
# height 0.14 m command -> SetStandHeight
# height 0.14 m -> FSM 4   mode 0
# height 0.16 m command -> SetStandHeight
# height 0.16 m -> FSM 4   mode 0
# height 0.18 m command -> SetStandHeight
# height 0.18 m -> FSM 4   mode 0
# height 0.20 m command -> SetStandHeight
# height 0.20 m -> FSM 4   mode 0
# height 0.22 m command -> SetStandHeight
# height 0.22 m -> FSM 4   mode 0
# Robot appears loaded. Confirm before commanding balanced stand. Press Enter to continue.
# ...

# %%
rob.release_fingers("both")

# %%
result = rob.extend_arm_forward(arm="right", duration_s=4.0, command_rate_hz=50.0)

# %%
result = rob.extend_arm_forward(arm="left", duration_s=4.0, command_rate_hz=50.0)

# %%
rob.hand_open("right")

# %%
rob.hand_open("left")

# %%
RIGHT_ELBOW = 25
current_elbow = rob.get_joint_position("right_arm.elbow")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.75, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)

# %%
RIGHT_ELBOW = 26
current_elbow = rob.get_joint_position("right_arm.wrist_roll")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.5, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)

# %%
RIGHT_ELBOW = 19
current_elbow = rob.get_joint_position("left_arm.wrist_roll")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.5, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)

# %%
#rob.walk(0.25,0.0,0.0)
#time.sleep(2)
#rob.stop()

# %%
rob.hand_close("right")

# %%
rob.hand_close("left")

# %%
RIGHT_ELBOW = 25
current_elbow = rob.get_joint_position("right_arm.elbow")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) + 0.2, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)

# %%
RIGHT_ELBOW = 18
current_elbow = rob.get_joint_position("left_arm.elbow")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.25, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)

# %%
RIGHT_ELBOW = 27
current_elbow = rob.get_joint_position("right_arm.wrist_pitch")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.25, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)
RIGHT_ELBOW = 24
current_elbow = rob.get_joint_position("right_arm.shoulder_yaw")
if current_elbow is None:
    raise RuntimeError("Could not read right elbow position.")

target_elbow = min(float(current_elbow) - 0.25, 2.0944)
lift_result = rob.move_upper_body_joint(
    RIGHT_ELBOW,
    target_elbow,
    command_rate_hz=50.0,
    max_speed_rad_s=0.25,
)
rob.hand_open("right")

# %%
#rob.walk(0.0,-0.3,0.0)
#time.sleep(2)
#rob.stop()

# %%
rob.hand_close("left")

# %%
rob.balanced_stand()

# %%
rob.walk(-0.25,0.0,0.0)
# Out:
# 0

# %%
rob.stop()

# %%
rob.retract_arm_forward(arm="right", duration_s=4.0, command_rate_hz=50.0)
# Out:
# {'arm': 'right',
#  'start_pose': [0.2906414270401001,
#   -0.2051699310541153,
#   0.03706720843911171,
#   0.9837610721588135,
#   -0.14921559393405914,
#   0.04284360632300377,
#   0.019666112959384918],
#  'wrist_and_elbow_retracted_pose': [0.2906414270401001,
#   -0.2051699310541153,
#   0.03706720843911171,
#   1.8837610721588134,
#   -0.39921559393405914,
#   0.7928436063230038,
#   0.019666112959384918],
#  'clearance_roll_pose': [0.2906414270401001,
#   -0.4301699310541153,
#   0.03706720843911171,
#   1.8837610721588134,
#   -0.39921559393405914,
#   0.7928436063230038,
#   0.019666112959384918],
#  'shoulder_pitch_retracted_pose': [0.6406414270401001,
#   -0.4301699310541153,
#   0.03706720843911171,
#   1.8837610721588134,
#   -0.39921559393405914,
#   0.7928436063230038,
#   0.019666112959384918],
#  'target_pose': [0.6406414270401001,
#   0.06983006894588473,
#   0.03706720843911171,
#   1.8837610721588134,
#   -0.39921559393405914,
#   0.7928436063230038,
# ...

# %%
rob.damp()

# %%
rob.release_arms()
# Out:
# {'duration_s': 3.0, 'command_rate_hz': 50.0, 'final_arm_sdk_weight': 0.0}

# %%
rob.shake_hand(release_after_s=60)
# Out:
# 3104

# %%
rob.high_wave()
# Out:
# 3104

# %%
rob.unrelease_arms(duration_s=1.5, command_rate_hz=50, kp=30.0, kd=1.5)
# Out:
# {'duration_s': 1.5,
#  'command_rate_hz': 50.0,
#  'final_arm_sdk_weight': 1.0,
#  'joint_count': 17}
