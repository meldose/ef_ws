# %%
from sdk_client import Robot
rob = Robot("eth0")

# %%
rob.debug_api()
# Out:
# [start_mapping (1801)]
# request: {
#   "data": {
#     "slam_type": "indoor"
#   }
# }
# response: code=0 raw={"succeed":true,"errorCode":0,"info":"Successfully started mapping.","data":{}}
#
# [end_mapping (1802)]
# request: {
#   "data": {
#     "address": "/home/unitree/test1.pcd"
#   }
# }
# response: code=1 raw={"succeed":false,"errorCode":505,"info":"Pcd buffer less than 1.","data":{}}
#
# [init_pose (1804)]
# request: {
#   "data": {
#     "x": 0.0,
#     "y": 0.0,
#     "z": 0.0,
#     "q_x": 0.0,
#     "q_y": 0.0,
#     "q_z": 0.0,
#     "q_w": 1.0,
#     "address": "/home/unitree/test1.pcd"
#   }
# }
# response: code=1 raw={"succeed":false,"errorCode":507,"info":"Load pcd failed.","data":{}}
#
# [pose_nav (1102)]
# request: {
#   "data": {
#     "targetPose": {
#       "x": 1.0,
#       "y": 0.0,
#       "z": 0.0,
#       "q_x": 0.0,
#       "q_y": 0.0,
#       "q_z": 0.0,
#       "q_w": 1.0
#     },
#     "mode": 1
#   }
# }
# ...
