# %%
from sdk_client import Robot
rob = Robot("eth0")

# %%
import time
rob.walk(0.5,0.0,0.0)
time.sleep(5)
rob.stop()

# %%
rob.turn_for(-45)
# Out:
# False

# %%
rob.fsm_1_damp()

# %%
rob.fsm_0_zt()

# %%
rob.get_joint_position(1)
# Out:
# -0.019225891679525375

# %%
rob.get_imu()
# Out:
# ImuData(rpy=(-0.0010206986917182803, 0.049469489604234695, -1.5879878997802734), gyro=(0.0, 0.0, 0.0), acc=(0.0, 0.0, 0.0), quat=(-0.7007970809936523, -0.017280351370573044, -0.017701199278235435, 0.7129316329956055), temp=0.0)

# %%
rob.get_odom_pose()

# %%
rob.get_slam_info()

# %%
rob.get_slam_pose()
# Out:
# (0.0, 0.0, 0.0)

# %%
rob.hanged_boot()
# Out:
# damp         -> FSM 4   mode 1
# stand_up     -> FSM None   mode 0
# height 0.02 m -> FSM 4   mode 0
# height 0.04 m -> FSM 4   mode None
# height 0.06 m -> FSM None   mode None
# height 0.08 m -> FSM None   mode None
# height 0.10 m -> FSM 501   mode 0
# height 0.12 m -> FSM 501   mode 0
# height 0.14 m -> FSM 501   mode 0
# height 0.16 m -> FSM 501   mode None
# height 0.18 m -> FSM 501   mode 0
# height 0.20 m -> FSM 501   mode 0
# height 0.22 m -> FSM 501   mode 0
# Feet still unloaded (mode 0) after reaching 0.22 m. Adjust the hanger height, then press Enter to retry.
# reset        -> FSM None   mode None

# %%
rob.get_robot_state()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rob.get_robot_state()
#
# NameError: name 'rob' is not defined

# %%
rob.hand_close("right")

# %%
rob.hand_open("right")

# %%
rob.set_gait_type(0)
# Out:
# 0
